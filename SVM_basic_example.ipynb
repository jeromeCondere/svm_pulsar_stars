# %% [markdown]
# # Pulsar stars prediction using SVM
#
# ## Data exploration

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

# %%
df = pd.read_csv("pulsar_stars.csv")

# %%
df.shape
# Out:
# (17898, 9)

# %%
df.head()
# Out:
#     Mean of the integrated profile  \
# 0                       140.562500
# 1                       102.507812
# 2                       103.015625
# 3                       136.750000
# 4                        88.726562
#
#     Standard deviation of the integrated profile  \
# 0                                      55.683782
# 1                                      58.882430
# 2                                      39.341649
# 3                                      57.178449
# 4                                      40.672225
#
#     Excess kurtosis of the integrated profile  \
# 0                                   -0.234571
# 1                                    0.465318
# 2                                    0.323328
# 3                                   -0.068415
# 4                                    0.600866
#
#     Skewness of the integrated profile   Mean of the DM-SNR curve  \
# 0                            -0.699648                   3.199833
# ...

# %%
df.describe()
# Out:
#         Mean of the integrated profile  \
# count                     17898.000000
# mean                        111.079968
# std                          25.652935
# min                           5.812500
# 25%                         100.929688
# 50%                         115.078125
# 75%                         127.085938
# max                         192.617188
#
#         Standard deviation of the integrated profile  \
# count                                   17898.000000
# mean                                       46.549532
# std                                         6.843189
# min                                        24.772042
# 25%                                        42.376018
# 50%                                        46.947479
# 75%                                        51.023202
# max                                        98.778911
#
#         Excess kurtosis of the integrated profile  \
# count                                17898.000000
# ...

# %% [markdown]
# ## Pair plot

# %%
sns.pairplot(data=df,
             palette="husl",
             hue="target_class",
             vars=[" Mean of the integrated profile",
                   " Excess kurtosis of the integrated profile",
                   " Skewness of the integrated profile",
                   " Mean of the DM-SNR curve",
                   " Excess kurtosis of the DM-SNR curve",
                   " Skewness of the DM-SNR curve"])

plt.suptitle("PairPlot Without Std. Dev. Fields",fontsize=18)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Correlation matrix

# %%
plt.figure(figsize=(16,12))
sns.heatmap(data=df.corr(),annot=True,cmap="bone",linewidths=1,fmt=".2f",linecolor="gray")
plt.title("Correlation Matrix",fontsize=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## SVM

# %%
df.columns = ['IP Mean', 'IP Sd', 'IP Kurtosis', 'IP Skewness', 
              'DM-SNR Mean', 'DM-SNR Sd', 'DM-SNR Kurtosis', 'DM-SNR Skewness', 'target_class']

# %%
df['target_class'].value_counts()/np.float(len(df))
# Out:
# 0    0.908426
# 1    0.091574
# Name: target_class, dtype: float64

# %% [markdown]
# We have 9.1% of pulsar star, now let's check for missing values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17898 entries, 0 to 17897
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   IP Mean          17898 non-null  float64
#  1   IP Sd            17898 non-null  float64
#  2   IP Kurtosis      17898 non-null  float64
#  3   IP Skewness      17898 non-null  float64
#  4   DM-SNR Mean      17898 non-null  float64
#  5   DM-SNR Sd        17898 non-null  float64
#  6   DM-SNR Kurtosis  17898 non-null  float64
#  7   DM-SNR Skewness  17898 non-null  float64
#  8   target_class     17898 non-null  int64
# dtypes: float64(8), int64(1)
# memory usage: 1.2 MB

# %% [markdown]
# No null values, we can proceed

# %%
X = df.drop(['target_class'], axis=1)

y = df['target_class']

X_train, X_test, Y_train, Y_test = train_test_split(X,y,test_size=0.25)
cols=X_train.columns

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)

X_test = scaler.transform(X_test)


X_train = pd.DataFrame(X_train, columns=[cols])
X_test = pd.DataFrame(X_test, columns=[cols])

# %%
svm_model = SVC(random_state=42,kernel="poly",probability=True)

svm_model.fit(X_train,Y_train)
# Out:
# SVC(kernel='poly', probability=True, random_state=42)

# %%
y_head_svm = svm_model.predict(X_test)
svm_score = svm_model.score(X_test,Y_test)

print('SVM model accuracy score {0:0.4f}'.format(svm_score))
# Out:
# Svm model score 0.9781

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(Y_test, y_head_svm)

print('Confusion matrix\n\n', cm)

print('\nTrue Positives(TP) = ', cm[0,0])

print('\nTrue Negatives(TN) = ', cm[1,1])

print('\nFalse Positives(FP) = ', cm[0,1])

print('\nFalse Negatives(FN) = ', cm[1,0])
# Out:
# Confusion matrix
#
#  [[4046   14]
#  [  84  331]]
#
# True Positives(TP) =  4046
#
# True Negatives(TN) =  331
#
# False Positives(FP) =  14
#
# False Negatives(FN) =  84
